# %% [markdown]
# # **(Insert Title Here)**
# ## **Summer 2024 Data Science Project**
# ### By: Shiven Chokshi, Dave Jose, Sujithkumar Manoharan, Rahul Yarlagadda
#
# ### **Introduction**
#
# Answer the following here:
#
# The introduction should motivate your work: what is your topic? What question(s) are you trying to answer with your analysis? Why is answering those questions important?
#
# ### **Data Curation**
#
# Cite the source(s) of your data. Explain what it is.

# %%
import pandas as pd
platforms_df = pd.read_csv("video-game-sales-all-platforms.csv")
series_df = pd.read_csv("video-game-sales-series.csv")
titles_df = pd.read_csv("video-game-sales-titles.csv")

# %% [markdown]
# #### **Data Preproccesing**

# %%
platforms_df
#platforms_df = pd.read_csv("video-game-sales-all-platforms.csv").drop(columns = 'Last Update', axis = 1).dropna().drop_duplicates()
#series_df = pd.read_csv("video-game-sales-series.csv").drop(columns = 'Last Update', axis = 1).dropna().drop_duplicates()
#titles_df = pd.read_csv("video-game-sales-titles.csv").drop(columns = ['VGChartz Score', 'Critic Score', 'User Score', 'NA Sales', 'PAL Sales', 'Japan Sales', 'Other Sales', 'Last Update'], axis = 1).drop_duplicates()
# Out:
#       Rank                          Title                       Publisher  \
# 0        1                      Minecraft                          Mojang
# 1        2             Grand Theft Auto V                  Rockstar Games
# 2        3  PlayerUnknown's Battlegrounds                PUBG Corporation
# 3        4    The Elder Scrolls V: Skyrim              Bethesda Softworks
# 4        5          Red Dead Redemption 2                  Rockstar Games
# ...    ...                            ...                             ...
# 1029  1030          Football Manager 2022                         Unknown
# 1030  1031            Deltarune Chapter 2                         Unknown
# 1031  1032                      Days Gone  Sony Interactive Entertainment
# 1032  1033                         ARK II                         Unknown
# 1033  1034          Football Manager 2023                         Unknown
#
#                   Developer  Total Sales Release Date Last Update  \
# 0                 Mojang AB  238000000.0   11/18/2011   10/8/2020
# 1            Rockstar North  180000000.0    9/17/2013   10/8/2020
# 2          PUBG Corporation   70000000.0   12/17/2017  10/24/2020
# 3     Bethesda Game Studios   60000000.0   11/10/2011  10/27/2020
# 4          Rockstar Studios   53000000.0   10/26/2018   10/8/2020
# ...                     ...          ...          ...         ...
# 1029     Sports Interactive          NaN          NaN   9/11/2021
# 1030               Toby Fox          NaN          NaN  12/23/2021
# 1031        SIE Bend Studio          NaN    4/26/2019    1/6/2022
# 1032        Studio Wildcard          NaN          NaN   6/13/2022
# 1033     Sports Interactive          NaN          NaN  10/30/2022
#
#                  Genre
# 0     Action-Adventure
# 1     Action-Adventure
# 2              Shooter
# 3         Role-Playing
# 4     Action-Adventure
# ...                ...
# 1029        Simulation
# 1030      Role-Playing
# 1031  Action-Adventure
# 1032  Action-Adventure
# 1033        Simulation
#
# [1034 rows x 8 columns]

# %% [markdown]
# As we can see, there is a column called "Last Update," however, we will not utilize that data so we will filter it out.

# %%
platforms_df_1 = platforms_df.drop(columns = 'Last Update', axis = 1)
platforms_df_1
# Out:
#       Rank                          Title                       Publisher  \
# 0        1                      Minecraft                          Mojang
# 1        2             Grand Theft Auto V                  Rockstar Games
# 2        3  PlayerUnknown's Battlegrounds                PUBG Corporation
# 3        4    The Elder Scrolls V: Skyrim              Bethesda Softworks
# 4        5          Red Dead Redemption 2                  Rockstar Games
# ...    ...                            ...                             ...
# 1029  1030          Football Manager 2022                         Unknown
# 1030  1031            Deltarune Chapter 2                         Unknown
# 1031  1032                      Days Gone  Sony Interactive Entertainment
# 1032  1033                         ARK II                         Unknown
# 1033  1034          Football Manager 2023                         Unknown
#
#                   Developer  Total Sales Release Date             Genre
# 0                 Mojang AB  238000000.0   11/18/2011  Action-Adventure
# 1            Rockstar North  180000000.0    9/17/2013  Action-Adventure
# 2          PUBG Corporation   70000000.0   12/17/2017           Shooter
# 3     Bethesda Game Studios   60000000.0   11/10/2011      Role-Playing
# 4          Rockstar Studios   53000000.0   10/26/2018  Action-Adventure
# ...                     ...          ...          ...               ...
# 1029     Sports Interactive          NaN          NaN        Simulation
# 1030               Toby Fox          NaN          NaN      Role-Playing
# 1031        SIE Bend Studio          NaN    4/26/2019  Action-Adventure
# 1032        Studio Wildcard          NaN          NaN  Action-Adventure
# 1033     Sports Interactive          NaN          NaN        Simulation
#
# [1034 rows x 7 columns]

# %% [markdown]
# Now, we see a lot of "NaN" values which are not useful for analysis, so we will filter those out along with any duplicates that may be present in the data.

# %%
platforms_df_final = platforms_df_1.dropna().drop_duplicates()
platforms_df_final
# Out:
#       Rank                          Title                Publisher  \
# 0        1                      Minecraft                   Mojang
# 1        2             Grand Theft Auto V           Rockstar Games
# 2        3  PlayerUnknown's Battlegrounds         PUBG Corporation
# 3        4    The Elder Scrolls V: Skyrim       Bethesda Softworks
# 4        5          Red Dead Redemption 2           Rockstar Games
# ...    ...                            ...                      ...
# 1005  1006                The Warp Factor    Strategic Simulations
# 1006  1007                      Horizon V         Gebelli Software
# 1007  1008                 Canyon Climber        Tandy Corporation
# 1008  1009                    DragonQuest                     Enix
# 1009  1010                     Rear Guard  Adventure International
#
#                      Developer  Total Sales Release Date             Genre
# 0                    Mojang AB  238000000.0   11/18/2011  Action-Adventure
# 1               Rockstar North  180000000.0    9/17/2013  Action-Adventure
# 2             PUBG Corporation   70000000.0   12/17/2017           Shooter
# 3        Bethesda Game Studios   60000000.0   11/10/2011      Role-Playing
# 4             Rockstar Studios   53000000.0   10/26/2018  Action-Adventure
# ...                        ...          ...          ...               ...
# 1005     Strategic Simulations      10000.0     1/1/1980        Simulation
# 1006          Gebelli Software      10000.0     1/1/1982              Misc
# 1007               Steve Bjork      10000.0     1/1/1982          Platform
# 1008  Simulations Publications      10000.0    5/27/1986      Role-Playing
# 1009   Adventure International          0.0    12/1/1981           Shooter
#
# [1005 rows x 7 columns]

# %% [markdown]
# This data now looks ready to analyze. Now we focus on cleaning the next dataset: video game series.

# %%
series_df
# Out:
#      Rank              Title              Publisher              Developer  \
# 0       1             Tetris     The Tetris Company        Alexey Pajitnov
# 1       2            Pokemon               Nintendo             Game Freak
# 2       3        Super Mario               Nintendo               Nintendo
# 3       4   Grand Theft Auto         Rockstar Games         Rockstar North
# 4       5       Call of Duty             Activision          Infinity Ward
# ..    ...                ...                    ...                    ...
# 410   411           Yomawari            NIS America   Nippon Ichi Software
# 411   412    Savage Frontier  Strategic Simulations        Beyond Software
# 412   413           Gemstone  Strategic Simulations      Paradigm Creators
# 413   414            Roadwar  Strategic Simulations  Strategic Simulations
# 414   415  Detective Pikachu               Nintendo              Creatures
#
#      Total Sales Release Date Last Update             Genre
# 0    496400000.0     1/1/1988   2/27/2020            Puzzle
# 1    480660000.0    9/28/1998    2/3/2020      Role-Playing
# 2    401830000.0    7/20/1983   2/20/2020          Platform
# 3    400000000.0    3/27/1998    2/3/2020  Action-Adventure
# 4    400000000.0   10/29/2003    2/3/2020           Shooter
# ..           ...          ...         ...               ...
# 410     100000.0   10/25/2016    2/3/2021         Adventure
# 411      90000.0     1/1/1991   3/22/2021      Role-Playing
# 412      60000.0     1/1/1984   3/25/2021  Action-Adventure
# 413      60000.0     1/1/1986   3/25/2021          Strategy
# 414          NaN    3/23/2018   6/21/2023         Adventure
#
# [415 rows x 8 columns]

# %% [markdown]
# As we can see, there is also a column here called "Last Update," which as we stated before, will not use in our analysis so it will be filtered out again.

# %%
series_df_1 = series_df.drop(columns = 'Last Update', axis = 1)
series_df_1
# Out:
#      Rank              Title              Publisher              Developer  \
# 0       1             Tetris     The Tetris Company        Alexey Pajitnov
# 1       2            Pokemon               Nintendo             Game Freak
# 2       3        Super Mario               Nintendo               Nintendo
# 3       4   Grand Theft Auto         Rockstar Games         Rockstar North
# 4       5       Call of Duty             Activision          Infinity Ward
# ..    ...                ...                    ...                    ...
# 410   411           Yomawari            NIS America   Nippon Ichi Software
# 411   412    Savage Frontier  Strategic Simulations        Beyond Software
# 412   413           Gemstone  Strategic Simulations      Paradigm Creators
# 413   414            Roadwar  Strategic Simulations  Strategic Simulations
# 414   415  Detective Pikachu               Nintendo              Creatures
#
#      Total Sales Release Date             Genre
# 0    496400000.0     1/1/1988            Puzzle
# 1    480660000.0    9/28/1998      Role-Playing
# 2    401830000.0    7/20/1983          Platform
# 3    400000000.0    3/27/1998  Action-Adventure
# 4    400000000.0   10/29/2003           Shooter
# ..           ...          ...               ...
# 410     100000.0   10/25/2016         Adventure
# 411      90000.0     1/1/1991      Role-Playing
# 412      60000.0     1/1/1984  Action-Adventure
# 413      60000.0     1/1/1986          Strategy
# 414          NaN    3/23/2018         Adventure
#
# [415 rows x 7 columns]

# %% [markdown]
# Now, we see some "NaN" values here as well, so we will filter out those rows along with any present duplicate data.

# %%
series_df_final = series_df_1.dropna().drop_duplicates()
series_df_final
# Out:
#      Rank             Title              Publisher              Developer  \
# 0       1            Tetris     The Tetris Company        Alexey Pajitnov
# 1       2           Pokemon               Nintendo             Game Freak
# 2       3       Super Mario               Nintendo               Nintendo
# 3       4  Grand Theft Auto         Rockstar Games         Rockstar North
# 4       5      Call of Duty             Activision          Infinity Ward
# ..    ...               ...                    ...                    ...
# 409   410        Planetfall                Infocom          Infocom, Inc.
# 410   411          Yomawari            NIS America   Nippon Ichi Software
# 411   412   Savage Frontier  Strategic Simulations        Beyond Software
# 412   413          Gemstone  Strategic Simulations      Paradigm Creators
# 413   414           Roadwar  Strategic Simulations  Strategic Simulations
#
#      Total Sales Release Date             Genre
# 0    496400000.0     1/1/1988            Puzzle
# 1    480660000.0    9/28/1998      Role-Playing
# 2    401830000.0    7/20/1983          Platform
# 3    400000000.0    3/27/1998  Action-Adventure
# 4    400000000.0   10/29/2003           Shooter
# ..           ...          ...               ...
# 409     100000.0     7/8/1983         Adventure
# 410     100000.0   10/25/2016         Adventure
# 411      90000.0     1/1/1991      Role-Playing
# 412      60000.0     1/1/1984  Action-Adventure
# 413      60000.0     1/1/1986          Strategy
#
# [414 rows x 7 columns]

# %% [markdown]
# This data now looks ready to analyze. Now we focus on cleaning the last dataset: video games by titles.

# %%
titles_df
# Out:
#         Rank                             Title Console           Publisher  \
# 0          1                        Wii Sports     Wii            Nintendo
# 1          2               Mario Kart 8 Deluxe      NS            Nintendo
# 2          3     Animal Crossing: New Horizons      NS            Nintendo
# 3          4                 Super Mario Bros.     NES            Nintendo
# 4          5  Counter-Strike: Global Offensive      PC               Valve
# ...      ...                               ...     ...                 ...
# 54546  54547                      Zwei II Plus      PC  Falcom Corporation
# 54547  54548                       Zwei Worter      PC            Clock Up
# 54548  54549                            Zwei!!      PC  Falcom Corporation
# 54549  54550                            Zwei!!     PS2               Taito
# 54550  54551                            Zyklus      PC                 F&C
#
#                       Developer  VGChartz Score  Critic Score  User Score  \
# 0                  Nintendo EAD             NaN           7.7         NaN
# 1                  Nintendo EPD             NaN           9.3         NaN
# 2                      Nintendo             8.0           NaN         NaN
# 3                  Nintendo EAD             NaN          10.0         8.2
# 4             Valve Corporation             NaN           NaN         NaN
# ...                         ...             ...           ...         ...
# 54546  Nihon Falcom Corporation             NaN           NaN         NaN
# 54547                  Team DYO             NaN           NaN         NaN
# 54548  Nihon Falcom Corporation             NaN           NaN         NaN
# 54549  Nihon Falcom Corporation             NaN           NaN         NaN
# 54550                       F&C             NaN           NaN         NaN
#
#        Total Sales  NA Sales  PAL Sales  Japan Sales  Other Sales  \
# 0       82900000.0       NaN        NaN          NaN          NaN
# 1       55460000.0       NaN        NaN          NaN          NaN
# 2       42790000.0       NaN        NaN          NaN          NaN
# 3       40240000.0       NaN        NaN          NaN          NaN
# 4       40000000.0       NaN        NaN          NaN          NaN
# ...            ...       ...        ...          ...          ...
# 54546          NaN       NaN        NaN          NaN          NaN
# 54547          NaN       NaN        NaN          NaN          NaN
# 54548          NaN       NaN        NaN          NaN          NaN
# 54549          NaN       NaN        NaN          NaN          NaN
# 54550          NaN       NaN        NaN          NaN          NaN
#
#       Release Date Last Update         Genre
# 0       11/19/2006         NaN        Sports
# 1        4/28/2017  11/19/2018        Racing
# 2        3/20/2020   4/11/2020    Simulation
# 3       10/18/1985         NaN      Platform
# 4        8/21/2012   3/26/2019       Shooter
# ...            ...         ...           ...
# 54546   12/24/2009         NaN  Role-Playing
# 54547    4/27/2007         NaN     Adventure
# 54548     1/1/2001         NaN  Role-Playing
# 54549    8/26/2004         NaN  Role-Playing
# 54550    4/30/2003         NaN     Adventure
#
# [54551 rows x 16 columns]

# %% [markdown]
# As we can see the "Last Update" column is here again so it will be filtered out. We also see multiple regional sales columns such as NA Sales, PAL Sales, Japan Sales, and Other Sales which look to be mostly filled with "NaN" values. In addition, there are three columns that track various scores for each games (VGChartz Score, Critic Score, User Score). However, we do not plan on using this data either. So, all of these columns will be filtered out.

# %%
titles_df_1 = titles_df.drop(columns = ['VGChartz Score', 'Critic Score', 'User Score', 'NA Sales', 'PAL Sales', 'Japan Sales', 'Other Sales', 'Last Update'], axis = 1)
titles_df_1
# Out:
#         Rank                             Title Console           Publisher  \
# 0          1                        Wii Sports     Wii            Nintendo
# 1          2               Mario Kart 8 Deluxe      NS            Nintendo
# 2          3     Animal Crossing: New Horizons      NS            Nintendo
# 3          4                 Super Mario Bros.     NES            Nintendo
# 4          5  Counter-Strike: Global Offensive      PC               Valve
# ...      ...                               ...     ...                 ...
# 54546  54547                      Zwei II Plus      PC  Falcom Corporation
# 54547  54548                       Zwei Worter      PC            Clock Up
# 54548  54549                            Zwei!!      PC  Falcom Corporation
# 54549  54550                            Zwei!!     PS2               Taito
# 54550  54551                            Zyklus      PC                 F&C
#
#                       Developer  Total Sales Release Date         Genre
# 0                  Nintendo EAD   82900000.0   11/19/2006        Sports
# 1                  Nintendo EPD   55460000.0    4/28/2017        Racing
# 2                      Nintendo   42790000.0    3/20/2020    Simulation
# 3                  Nintendo EAD   40240000.0   10/18/1985      Platform
# 4             Valve Corporation   40000000.0    8/21/2012       Shooter
# ...                         ...          ...          ...           ...
# 54546  Nihon Falcom Corporation          NaN   12/24/2009  Role-Playing
# 54547                  Team DYO          NaN    4/27/2007     Adventure
# 54548  Nihon Falcom Corporation          NaN     1/1/2001  Role-Playing
# 54549  Nihon Falcom Corporation          NaN    8/26/2004  Role-Playing
# 54550                       F&C          NaN    4/30/2003     Adventure
#
# [54551 rows x 8 columns]

# %% [markdown]
# Now that the unnecessary columns have been filtered out, we see there are still some "NaN" values present so we will drop those rows in addition to any duplicate data that may be present.

# %%
titles_df_final = titles_df_1.dropna().drop_duplicates()
titles_df_final
# Out:
#         Rank                               Title Console  \
# 0          1                          Wii Sports     Wii
# 1          2                 Mario Kart 8 Deluxe      NS
# 2          3       Animal Crossing: New Horizons      NS
# 3          4                   Super Mario Bros.     NES
# 4          5    Counter-Strike: Global Offensive      PC
# ...      ...                                 ...     ...
# 21275  21276            Zoids Assault (JP sales)    X360
# 21276  21277                          Zoo Empire      PC
# 21277  21278     Zoo Tycoon 2: African Adventure      PC
# 21278  21279    Zoo Tycoon 2: Endangered Species      PC
# 21279  21280  Zoo Tycoon 2: Zookeeper Collection      PC
#
#                     Publisher          Developer  Total Sales Release Date  \
# 0                    Nintendo       Nintendo EAD   82900000.0   11/19/2006
# 1                    Nintendo       Nintendo EPD   55460000.0    4/28/2017
# 2                    Nintendo           Nintendo   42790000.0    3/20/2020
# 3                    Nintendo       Nintendo EAD   40240000.0   10/18/1985
# 4                       Valve  Valve Corporation   40000000.0    8/21/2012
# ...                       ...                ...          ...          ...
# 21275                   Atlus              Atlus          0.0    9/16/2008
# 21276                 Enlight   Enlight Software          0.0     8/1/2004
# 21277  Microsoft Game Studios    Blue Fang Games          0.0    5/22/2006
# 21278  Microsoft Game Studios    Blue Fang Games          0.0   10/19/2005
# 21279  Microsoft Game Studios    Blue Fang Games          0.0    10/1/2006
#
#             Genre
# 0          Sports
# 1          Racing
# 2      Simulation
# 3        Platform
# 4         Shooter
# ...           ...
# 21275    Strategy
# 21276  Simulation
# 21277    Strategy
# 21278    Strategy
# 21279    Strategy
#
# [20739 rows x 8 columns]

# %% [markdown]
# ### **Exploratory Data Analysis**
# #### Hypothesis Test #1: Average Total Sales Among Publishers

# %% [markdown]
# - $H_{0}$: There is no significant difference in the average total sales among different publishers
#
# - $H_{A}$: There is a significant difference in the average total sales among different publishers

# %%
from scipy.stats import f_oneway
anova_data_all = [group['Total Sales'].values for name, group in series_df_final.groupby('Publisher')]
f_oneway(*anova_data_all).pvalue
# Out:
# 0.712728306874091

# %% [markdown]
# > Since the P-Value obtained (~ 0.713) is much higher than our confidence level (0.05) we fail to reject the null hypothesis. The high P-Value indicates that there is insufficient evidence to suggest that the publisher of a video game series has an effect on their average total sales. We chose to use the ANOVA test here since there are more than two groups to compare mean total sales.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

total_sales_per_publisher = series_df_final.groupby('Publisher')['Total Sales'].sum().sort_values(ascending=False)
top_20_publishers_by_sales = total_sales_per_publisher.index[:20]
filtered_data_by_sales = series_df_final[series_df_final['Publisher'].isin(top_20_publishers_by_sales)]
final_data_top_20_by_sales = filtered_data_by_sales[['Publisher', 'Total Sales']].dropna()
plt.figure(figsize = (16, 10))
sns.boxplot(data = final_data_top_20_by_sales, x = 'Total Sales', y = 'Publisher', palette = 'Set3')
plt.xlabel('Total Sales')
plt.ylabel('Publisher')
plt.title('Boxplot of Total Sales by Top 20 Publishers Based on Total Sales', fontsize = 16)
plt.grid(True, axis = 'x', linestyle = '--', alpha = 0.7)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/yx/zlnvjwgs24z0qh4n_jknp4c00000gn/T/ipykernel_36804/1415220307.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data = final_data_top_20_by_sales, x = 'Total Sales', y = 'Publisher', palette = 'Set3')

# %% [markdown]
# > Some publishers such as Nintendo have published a couple of hit video game series that outperformed the vast majority of their content causing them to be outliers while other publishers such as Activision have consistently pusblished multiple video game series that have performed around the same level relative to each other causing them to have no outliers. Most puslishers in the graph have a median total sale with the the interval of 10-40 million, aligning with our decision to fail to reject the null hypothesis which stated that there is no significant difference in average total sales among different publishers.

# %% [markdown]
# #### Hypothesis Test #2: Average Total Sales Between Action-Adventure and Shooter Games

# %% [markdown]
# - $H_{0}$: There is no significant difference in the average total sales between Action-Adventure and Shooter games
#
# - $H_{A}$: There is a significant difference in the average total sales between Action-Adventure and Shooter games

# %%
from scipy.stats import ttest_ind
action_adventure_sales = platforms_df_final[platforms_df_final['Genre'] == 'Action-Adventure']['Total Sales']
shooter_sales = platforms_df_final[platforms_df_final['Genre'] == 'Shooter']['Total Sales']
ttest_ind(action_adventure_sales, shooter_sales).pvalue
# Out:
# 0.4201934339363429

# %% [markdown]
# > Since the P-Value obtained (~ 0.42) is much higher than our confidence level (0.05) we fail to reject the null hypothesis. The high P-Value indicates that there is insufficient evidence to suggest that the difference in average total sales between the games in the Action-Adventure and Shooter genres. We decided to use the T-Test for this hypothesis test since we wanted to determine if there was a significant difference between the mean total sales between two groups and because we didn't know the population standard deviation and had to estimate it from the sample data.

# %%
genre_sales_data = platforms_df_final[platforms_df_final['Genre'].isin(['Action-Adventure', 'Shooter'])]
plt.figure(figsize = (12, 8))
sns.boxplot(data = genre_sales_data, x = 'Total Sales', y = 'Genre', palette = 'Set3')
plt.xlabel('Total Sales')
plt.ylabel('Genre')
plt.title('Boxplot of Total Sales: Action-Adventure vs. Shooter', fontsize = 16)
plt.grid(True, axis = 'x', linestyle = '--', alpha = 0.7)
plt.show()
# Out:
# /var/folders/yx/zlnvjwgs24z0qh4n_jknp4c00000gn/T/ipykernel_36804/123009734.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data = genre_sales_data, x = 'Total Sales', y = 'Genre', palette = 'Set3')

# %% [markdown]
# The distribution of Total Sales bewteen games in the Action-Adventure and Shooter genres are approximately the same as they have similar minimums, medians, interquartile ranges, maximums, and number of outliers with the only notable difference being that the outliers for the Action-Adventure genre are more spread out than those of the Shooter genre. This supports our decision to fail to reject the null hypothesis which stated that there is no significant difference between the average total sales between the Action-Adventure and Shooter genres.

# %% [markdown]
# #### Hypothesis Test #3: Association Between Release Year and Genre

# %% [markdown]
# - $H_{0}$: There is no association between release year and genre
#
# - $H_{A}$: There is an association between release year and genre

# %%
from scipy.stats import chi2_contingency
series_df_final['Release Year'] = pd.to_datetime(series_df_final['Release Date']).dt.year
contingency_table = pd.crosstab(series_df_final['Release Year'], series_df_final['Genre'])
chi2_contingency(contingency_table).pvalue
# Out:
# 0.5858676850144089

# %% [markdown]
# > Since the P-Value obtained (~ 0.586) is much higher than our confidence level (0.05) we fail to reject the null hypothesis. The high P-Value indicates that there is insufficient evidence to suggest that there is an association between a game's release year and genre. We decided to use the chi-squared test since we wanted to test if there was any significant association between two categorical variables: release year and genre.

# %%
heatmap_data = contingency_table.div(contingency_table.sum(axis = 1), axis = 0)
plt.figure(figsize = (14, 10))
sns.heatmap(heatmap_data, cmap = "YlGnBu", annot = True, fmt = ".2f", linewidths = 0.5)
plt.title('Heatmap of Genre Distribution by Release Year', fontsize = 16)
plt.xlabel('Genre')
plt.ylabel('Release Year')
plt.tight_layout()
plt.show()

# %% [markdown]
# > Based on the distribution shown in the heatmap, there is no significant correlation between the release year and the genre of the game released as different years have varying proportions of the genres of games released. This supports our decision to fail to reject the null hypothesis which stated that there is no relationship between release year and genre.

# %% [markdown]
# ### **Primary Analysis**

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score
from xgboost import XGBRegressor
import lightgbm as lgb
import numpy as np

X = platforms_df_final[['Genre', 'Publisher', 'Developer']]
y = platforms_df_final['Total Sales']

# One-hot encode categorical variables
one_hot_encoder = OneHotEncoder(sparse_output= False)
X_encoded = one_hot_encoder.fit_transform(X)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_encoded)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from kerastuner.tuners import RandomSearch
import keras_tuner as kt

def build_model(hp):
    model = Sequential()
    model.add(Dense(
        hp.Int('units1', min_value=32, max_value=512, step=32),
        activation='relu',
        input_dim=X_train.shape[1]
    ))
    model.add(Dropout(hp.Float('dropout1', min_value=0.1, max_value=0.5, step=0.1)))
    model.add(Dense(
        hp.Int('units2', min_value=32, max_value=512, step=32),
        activation='relu'
    ))
    model.add(Dropout(hp.Float('dropout2', min_value=0.1, max_value=0.5, step=0.1)))
    model.add(Dense(
        hp.Int('units3', min_value=32, max_value=512, step=32),
        activation='relu'
    ))
    model.add(Dense(1))

    model.compile(
        optimizer='adam',
        loss='mean_squared_error',
        metrics=['mean_squared_error']
    )
    return model

tuner = kt.Hyperband(
    build_model,
    objective='val_mean_squared_error',
    max_epochs=50,
    factor=3,
    directory='my_dir',
    project_name='test'
)

stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

tuner.search(X_train, y_train, epochs=50, validation_split=0.2, callbacks=[stop_early], verbose=2)

best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected layer is {best_hps.get('units1')}, 
with {best_hps.get('dropout1')} dropout rate, {best_hps.get('units2')} units in the second densely-connected layer, 
and {best_hps.get('dropout2')} dropout rate.
""")

# Train the best model
model = tuner.hypermodel.build(best_hps)
history = model.fit(X_train, y_train, epochs=100, validation_split=0.2, verbose=2, callbacks=[stop_early])

# Evaluate the best model
mse, _ = model.evaluate(X_test, y_test, verbose=0)
r2 = r2_score(y_test, model.predict(X_test))

print(f"Mean Squared Error: {mse}")
print(f"R^2 Score: {r2}")
# Out:
# Trial 90 Complete [00h 00m 08s]
# val_mean_squared_error: 190851955294208.0
#
# Best val_mean_squared_error So Far: 179686667714560.0
# Total elapsed time: 00h 06m 51s
#
# The hyperparameter search is complete. The optimal number of units in the first densely-connected layer is 512,
# with 0.5 dropout rate, 512 units in the second densely-connected layer,
# and 0.2 dropout rate.
#
# Epoch 1/100
# /usr/local/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 21/21 - 2s - 80ms/step - loss: 145874487345152.0000 - mean_squared_error: 145874487345152.0000 - val_loss: 241062488571904.0000 - val_mean_squared_error: 241062488571904.0000
# Epoch 2/100
# 21/21 - 0s - 19ms/step - loss: 145857710129152.0000 - mean_squared_error: 145857710129152.0000 - val_loss: 241014572843008.0000 - val_mean_squared_error: 241014572843008.0000
# Epoch 3/100
# 21/21 - 0s - 20ms/step - loss: 145752399544320.0000 - mean_squared_error: 145752399544320.0000 - val_loss: 240761857638400.0000 - val_mean_squared_error: 240761857638400.0000
# Epoch 4/100
# 21/21 - 0s - 21ms/step - loss: 145226517708800.0000 - mean_squared_error: 145226517708800.0000 - val_loss: 239804163817472.0000 - val_mean_squared_error: 239804163817472.0000
# Epoch 5/100
# 21/21 - 0s - 21ms/step - loss: 143907023224832.0000 - mean_squared_error: 143907023224832.0000 - val_loss: 237277464756224.0000 - val_mean_squared_error: 237277464756224.0000
# Epoch 6/100
# 21/21 - 0s - 19ms/step - loss: 140484664098816.0000 - mean_squared_error: 140484664098816.0000 - val_loss: 231986903908352.0000 - val_mean_squared_error: 231986903908352.0000
# Epoch 7/100
# 21/21 - 0s - 18ms/step - loss: 135333647745024.0000 - mean_squared_error: 135333647745024.0000 - val_loss: 224297436053504.0000 - val_mean_squared_error: 224297436053504.0000
# Epoch 8/100
# 21/21 - 0s - 20ms/step - loss: 128938659545088.0000 - mean_squared_error: 128938659545088.0000 - val_loss: 216303830827008.0000 - val_mean_squared_error: 216303830827008.0000
# Epoch 9/100
# 21/21 - 0s - 19ms/step - loss: 124391832682496.0000 - mean_squared_error: 124391832682496.0000 - val_loss: 210923696422912.0000 - val_mean_squared_error: 210923696422912.0000
# Epoch 10/100
# 21/21 - 0s - 18ms/step - loss: 121727451398144.0000 - mean_squared_error: 121727451398144.0000 - val_loss: 208738564702208.0000 - val_mean_squared_error: 208738564702208.0000
# Epoch 11/100
# 21/21 - 0s - 20ms/step - loss: 120350981488640.0000 - mean_squared_error: 120350981488640.0000 - val_loss: 206574706491392.0000 - val_mean_squared_error: 206574706491392.0000
# Epoch 12/100
# 21/21 - 0s - 19ms/step - loss: 118873193971712.0000 - mean_squared_error: 118873193971712.0000 - val_loss: 205736399339520.0000 - val_mean_squared_error: 205736399339520.0000
# Epoch 13/100
# 21/21 - 0s - 19ms/step - loss: 117626772652032.0000 - mean_squared_error: 117626772652032.0000 - val_loss: 203623678083072.0000 - val_mean_squared_error: 203623678083072.0000
# Epoch 14/100
# 21/21 - 0s - 19ms/step - loss: 116714536697856.0000 - mean_squared_error: 116714536697856.0000 - val_loss: 202679859019776.0000 - val_mean_squared_error: 202679859019776.0000
# Epoch 15/100
# 21/21 - 0s - 19ms/step - loss: 115948539346944.0000 - mean_squared_error: 115948539346944.0000 - val_loss: 202112587792384.0000 - val_mean_squared_error: 202112587792384.0000
# Epoch 16/100
# 21/21 - 0s - 20ms/step - loss: 114327449239552.0000 - mean_squared_error: 114327449239552.0000 - val_loss: 200274945769472.0000 - val_mean_squared_error: 200274945769472.0000
# Epoch 17/100
# 21/21 - 0s - 21ms/step - loss: 113183654150144.0000 - mean_squared_error: 113183654150144.0000 - val_loss: 198978754838528.0000 - val_mean_squared_error: 198978754838528.0000
# Epoch 18/100
# 21/21 - 0s - 22ms/step - loss: 111625797369856.0000 - mean_squared_error: 111625797369856.0000 - val_loss: 197832267005952.0000 - val_mean_squared_error: 197832267005952.0000
# Epoch 19/100
# 21/21 - 0s - 20ms/step - loss: 110979799056384.0000 - mean_squared_error: 110979799056384.0000 - val_loss: 196213181775872.0000 - val_mean_squared_error: 196213181775872.0000
# Epoch 20/100
# 21/21 - 0s - 20ms/step - loss: 109696023265280.0000 - mean_squared_error: 109696023265280.0000 - val_loss: 195345044733952.0000 - val_mean_squared_error: 195345044733952.0000
# Epoch 21/100
# 21/21 - 0s - 18ms/step - loss: 107847585103872.0000 - mean_squared_error: 107847585103872.0000 - val_loss: 193900408995840.0000 - val_mean_squared_error: 193900408995840.0000
# Epoch 22/100
# 21/21 - 0s - 19ms/step - loss: 106271164334080.0000 - mean_squared_error: 106271164334080.0000 - val_loss: 193015343742976.0000 - val_mean_squared_error: 193015343742976.0000
# Epoch 23/100
# 21/21 - 0s - 20ms/step - loss: 106940885630976.0000 - mean_squared_error: 106940885630976.0000 - val_loss: 191616845348864.0000 - val_mean_squared_error: 191616845348864.0000
# Epoch 24/100
# 21/21 - 0s - 20ms/step - loss: 104823005380608.0000 - mean_squared_error: 104823005380608.0000 - val_loss: 189791836569600.0000 - val_mean_squared_error: 189791836569600.0000
# Epoch 25/100
# 21/21 - 0s - 19ms/step - loss: 102474413244416.0000 - mean_squared_error: 102474413244416.0000 - val_loss: 188453635489792.0000 - val_mean_squared_error: 188453635489792.0000
# Epoch 26/100
# 21/21 - 0s - 18ms/step - loss: 102905663193088.0000 - mean_squared_error: 102905663193088.0000 - val_loss: 187935051743232.0000 - val_mean_squared_error: 187935051743232.0000
# Epoch 27/100
# 21/21 - 0s - 19ms/step - loss: 100312861900800.0000 - mean_squared_error: 100312861900800.0000 - val_loss: 187742768070656.0000 - val_mean_squared_error: 187742768070656.0000
# Epoch 28/100
# 21/21 - 0s - 16ms/step - loss: 97469962649600.0000 - mean_squared_error: 97469962649600.0000 - val_loss: 184921763086336.0000 - val_mean_squared_error: 184921763086336.0000
# Epoch 29/100
# 21/21 - 0s - 17ms/step - loss: 95405199065088.0000 - mean_squared_error: 95405199065088.0000 - val_loss: 183594567860224.0000 - val_mean_squared_error: 183594567860224.0000
# Epoch 30/100
# 21/21 - 0s - 16ms/step - loss: 95418318848000.0000 - mean_squared_error: 95418318848000.0000 - val_loss: 183411729760256.0000 - val_mean_squared_error: 183411729760256.0000
# Epoch 31/100
# 21/21 - 0s - 17ms/step - loss: 92628645314560.0000 - mean_squared_error: 92628645314560.0000 - val_loss: 183111417593856.0000 - val_mean_squared_error: 183111417593856.0000
# Epoch 32/100
# 21/21 - 0s - 15ms/step - loss: 93578177019904.0000 - mean_squared_error: 93578177019904.0000 - val_loss: 182030880997376.0000 - val_mean_squared_error: 182030880997376.0000
# Epoch 33/100
# 21/21 - 0s - 18ms/step - loss: 90773689204736.0000 - mean_squared_error: 90773689204736.0000 - val_loss: 181348450959360.0000 - val_mean_squared_error: 181348450959360.0000
# Epoch 34/100
# 21/21 - 0s - 19ms/step - loss: 90358486663168.0000 - mean_squared_error: 90358486663168.0000 - val_loss: 180843003772928.0000 - val_mean_squared_error: 180843003772928.0000
# Epoch 35/100
# 21/21 - 0s - 19ms/step - loss: 83112205746176.0000 - mean_squared_error: 83112205746176.0000 - val_loss: 179972937351168.0000 - val_mean_squared_error: 179972937351168.0000
# Epoch 36/100
# 21/21 - 0s - 17ms/step - loss: 86415882846208.0000 - mean_squared_error: 86415882846208.0000 - val_loss: 179595366105088.0000 - val_mean_squared_error: 179595366105088.0000
# Epoch 37/100
# 21/21 - 0s - 19ms/step - loss: 81392583049216.0000 - mean_squared_error: 81392583049216.0000 - val_loss: 179350804627456.0000 - val_mean_squared_error: 179350804627456.0000
# Epoch 38/100
# 21/21 - 0s - 16ms/step - loss: 76009319694336.0000 - mean_squared_error: 76009319694336.0000 - val_loss: 179175533051904.0000 - val_mean_squared_error: 179175533051904.0000
# Epoch 39/100
# 21/21 - 0s - 20ms/step - loss: 75843611131904.0000 - mean_squared_error: 75843611131904.0000 - val_loss: 178772829536256.0000 - val_mean_squared_error: 178772829536256.0000
# Epoch 40/100
# 21/21 - 0s - 19ms/step - loss: 73794240643072.0000 - mean_squared_error: 73794240643072.0000 - val_loss: 179462591217664.0000 - val_mean_squared_error: 179462591217664.0000
# Epoch 41/100
# 21/21 - 0s - 18ms/step - loss: 70863428780032.0000 - mean_squared_error: 70863428780032.0000 - val_loss: 179396405100544.0000 - val_mean_squared_error: 179396405100544.0000
# Epoch 42/100
# 21/21 - 0s - 18ms/step - loss: 69483645370368.0000 - mean_squared_error: 69483645370368.0000 - val_loss: 180314471137280.0000 - val_mean_squared_error: 180314471137280.0000
# Epoch 43/100
# 21/21 - 0s - 21ms/step - loss: 66667283480576.0000 - mean_squared_error: 66667283480576.0000 - val_loss: 180167485947904.0000 - val_mean_squared_error: 180167485947904.0000
# Epoch 44/100
# 21/21 - 0s - 19ms/step - loss: 66043657584640.0000 - mean_squared_error: 66043657584640.0000 - val_loss: 180684878512128.0000 - val_mean_squared_error: 180684878512128.0000
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x166056ac0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Mean Squared Error: 29473843970048.0
# R^2 Score: -0.5818001139729647
